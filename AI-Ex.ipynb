# %% [markdown]
# # Plan Semilla 3.0 - Artificial Intelligence Module

# %% [markdown]
# # State Space Search
#
# In this challenge you will implement some search algorithms for navigation problems.
#
# Your task is to create an autonomous vehicle that goes from point A to point B. You will be given some grid configurations that will simulate aerial images.
#
# The symbols that form the grid have a special meaning as they specify the type of the terrain and the cost to enter a grid cell with that type of terrain:

# %%
import numpy as np

print('Symbol', '   Meaning       ', 'Cost')
print('🛣', '       Street        ', 1)
print('🌲', '       Forest        ', 10)
print('🚸', '       School street ', 2)
print('🚦', '       Traffic light ', 3)
print('🚔', '       Police        ', 4)
print('🚘', '       Traffic       ', 6)
print('🛑', '       Stop sign     ', 5)
print('🚧', '       Construction  ', 7)
print('🏢', '       Buildings     ', 15)

COSTS = {'🛣': 1, '🌲': 10, '🚸': 2, '🚦': 3, '🚔': 4, '🚘': 6, '🛑': 5, '🚧': 7, '🏢': 15}
# Out:
# Symbol    Meaning        Cost
# 🛣        Street         1
# 🌲        Forest         10
# 🚸        School street  2
# 🚦        Traffic light  3
# 🚔        Police         4
# 🚘        Traffic        6
# 🛑        Stop sign      5
# 🚧        Construction   7
# 🏢        Buildings      15

# %%
test_map_1 = np.array([['🛣', '🛣', '🛣', '🛣'],
                       ['🛣', '🌲', '🌲', '🛣'],
                       ['🛣', '🌲', '🌲', '🛣'],
                       ['🛣', '🛣', '🛣', '🛣'],
                       ['🌲', '🛣', '🛣', '🛣']])

map1 = np.array([['🛣', '🚸', '🛣', '🛣', '🛣', '🛣', '🛣', '🛑', '🛣', '🛣', '🚦', '🛣', '🛣', '🛣', '🚔', '🛣'],
                 ['🛣', '🌲', '🌲', '🛣', '🛣', '🌲', '🌲', '🛣', '🛣', '🚘', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣'],
                 ['🛣', '🛣', '🛣', '🛣', '🛣', '🌲', '🌲', '🛣', '🛣', '🚘', '🛣', '🌲', '🌲', '🛣', '🚘', '🛣'],
                 ['🛣', '🛑', '🛣', '🚸', '🛣', '🌲', '🛣', '🛣', '🏢', '🛣', '🛣', '🌲', '🌲', '🛣', '🛣', '🚦'],
                 ['🌲', '🚘', '🚘', '🛣', '🛣', '🛣', '🚘', '🛣', '🏢', '🛣', '🛣', '🌲', '🛣', '🛑', '🛣', '🛣'],
                 ['🛣', '🛣', '🛣', '🏢', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🚦', '🛣', '🛣', '🛣', '🛣', '🚸'],
                 ['🛣', '🛣', '🏢', '🏢', '🏢', '🛣', '🛑', '🛣', '🛣', '🛣', '🚘', '🛣', '🛣', '🚸', '🛣', '🛣'],
                 ['🚦', '🛣', '🏢', '🚔', '🛣', '🛣', '🏢', '🚧', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🚔'],
                 ['🛣', '🛣', '🛣', '🚔', '🛣', '🛣', '🏢', '🏢', '🏢', '🚸', '🛣', '🛑', '🚘', '🚔', '🛣', '🛣'],
                 ['🛣', '🛑', '🛣', '🛣', '🛣', '🛣', '🏢', '🏢', '🏢', '🛣', '🛣', '🏢', '🛣', '🛣', '🛣', '🚘'],
                 ['🛣', '🛣', '🛣', '🌲', '🌲', '🚦', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🛣', '🚧', '🚘'],
                 ['🚘', '🚸', '🛣', '🌲', '🌲', '🛣', '🛣', '🛣', '🛣', '🚔', '🛣', '🛣', '🚦', '🚘', '🛣', '🛣'],
                 ['🚘', '🛣', '🚧', '🛣', '🛣', '🛣', '🛑', '🛣', '🚘', '🚘', '🛣', '🚘', '🛣', '🛣', '🛣', '🛣']])

# %%
class Agent:

    def __init__(self, world, costs, initial_state, goal_state):

        self.moves = np.array([[0,1], [0,-1], [-1,0], [1,0]])
        self.initial_state = initial_state
        self.goal_state = goal_state
        self.current_state = initial_state
        self.world = world
        self.costs = costs

    def possible_moves(self):

        succ_states, succ_actions, succ_costs = [],[],[]

        for move in self.moves:

            # check that the next state is in the range of the world
            #print(self.current_state)
            if 0 <= self.current_state[0] + move[0] < self.world.shape[0] and 0 <= self.current_state[1] + move[1] < self.world.shape[1]:

                # move and assign new_state to the position after moving
                new_state = [self.current_state[0] + move[0], self.current_state[1] + move[1]]

                action = [move[0], move[1]]

                cost = self.costs[self.world[new_state[0], new_state[1]]]

                succ_states.append(new_state)
                succ_actions.append(action)
                succ_costs.append(cost)

        return succ_states, succ_actions, succ_costs


    def set_current_state(self, nex_state):

        self.current_state = nex_state



class Node:

    def __init__(self, state, parent=None, action=None, cost=None):
        """Create a search tree Node, derived from a parent by an action."""
        self.state = state
        self.parent = parent
        self.action = action
        #self.cost = cost

        self.depth = 0
        self.path_cost = 0

        if parent:
            self.path_cost = parent.path_cost + cost
            self.depth = parent.depth + 1


    def successors(self, agent):

        succ_states, succ_actions, succ_costs = agent.possible_moves()
        children = []

        for i in range(len(succ_states)):

            children.append(Node(succ_states[i], self, succ_actions[i], succ_costs[i]))
        return  children

    def path(self):
        """Return a list of nodes forming the path from the root to this node."""
        node, path_back = self, []
        # TODO
        while node:
            path_back.append(node)
            node=node.parent
        return list(reversed(path_back))


def depth_first_graph_search(agent):
    #TODO
    """
    Search the deepest nodes in the search tree first.
    Search through the successors of a problem to find a goal.
    The argument frontier should be an empty queue.
    Does not get trapped by loops.
    If two paths reach a state, only use the first one.
    """
    frontier = [(Node(agent.initial_state))]  # Stack

    explored = []
    while frontier:
        print("stack:",frontier)
        print("stack reversed",list(reversed(frontier)))
        node=frontier.pop()    #while there's elements in the stack, pop top item and compare
        print("pop stack:",frontier)
        agent.set_current_state(node.state)
        print("agent.current_state",agent.current_state)
        print("node.state",node.state)
        print("node.parent",node.parent)
        print("node.depth",node.depth)
        print("node.action",node.action)
        print("node.path_cost",node.path_cost)
        if node.state==agent.goal_state:
            return node
        if node not in explored:
            explored.append(node)
        print("explored",explored)
        succesors=node.successors(agent)
        print("succesors",succesors)
        for item in succesors:
            if item not in explored and item not in frontier:
                frontier.append(item)
        print("stack",frontier)
        print("\n")
        if node.depth>15:
            break

        
        # print("succ_states",succ_states)
        # print("succ_actions",succ_actions)
        # print("succ_costs",succ_costs)

    return None

def breadth_first_graph_search(agent):
    #TODO
    """
    Search through the successors of a problem to find a goal.
    The argument frontier should be an empty queue.
    Does not get trapped by loops.
    If two paths reach a state, only use the first one.
    """
    frontier = [(Node(agent.initial_state))]  # Queue

    explored = []
    while frontier:
        pass
    return None



def uniform_cost_search(agent):
    #TODO
    """
    Search the deepest nodes in the search tree first.
    Search through the successors of a problem to find a goal.
    The argument frontier should be an empty queue.
    Does not get trapped by loops.
    If two paths reach a state, only use the first one.
    """
    frontier = [(Node(agent.initial_state))]  # Stack

    explored = []
    while frontier:
        pass

    return None


def order_frontier(frontier):

    costs = []
    new_list = []

    for i in range(len(frontier)):

        costs.append(frontier[i].path_cost)

    costs = np.array(costs)

    indexes = np.argsort(costs)

    for i in range(len(frontier)):

        new_list.append(frontier[indexes[i]])

    return list(reversed(new_list))



Ada = Agent(map1, COSTS, [0,0], [12,15])
# g_node = uniform_cost_search(Ada)
g_node=depth_first_graph_search(Ada)
print(g_node.state)
# print(g_node.state)

# p = g_node.path()

# moves = {'01':'⏩','0-1':'⏪','-10':'⏫', '10':'⏬'}

# map_copy = map1.copy()


# for i in range(len(p)-1):

#     ac = p[i]
#     n = p[i+1]

#     map_copy[ac.state[0], ac.state[1]] = moves[str(n.action[0])+str(n.action[1])]


# for i in range(map_copy.shape[0]):
#     print(map_copy[i,:])
# Out:
# stack: [<__main__.Node object at 0x000002317F07E1A0>]
# stack reversed [<__main__.Node object at 0x000002317F07E1A0>]
# pop stack: []
# agent.current_state [0, 0]
# node.state [0, 0]
# node.parent None
# node.depth 0
# node.action None
# node.path_cost 0
# explored [<__main__.Node object at 0x000002317F07E1A0>]
# succesors [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07D8D0>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07D8D0>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07D8D0>]
# stack reversed [<__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>]
# agent.current_state [1, 0]
# node.state [1, 0]
# node.parent <__main__.Node object at 0x000002317F07E1A0>
# node.depth 1
# node.action [1, 0]
# node.path_cost 1
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>]
# succesors [<__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07D900>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07D900>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07D900>]
# stack reversed [<__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>]
# agent.current_state [2, 0]
# node.state [2, 0]
# node.parent <__main__.Node object at 0x000002317F07D8D0>
# node.depth 2
# node.action [1, 0]
# node.path_cost 2
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>]
# succesors [<__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DD80>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DD80>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DD80>]
# stack reversed [<__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>]
# agent.current_state [3, 0]
# node.state [3, 0]
# node.parent <__main__.Node object at 0x000002317F07D900>
# node.depth 3
# node.action [1, 0]
# node.path_cost 3
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>]
# succesors [<__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E950>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E950>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E950>]
# stack reversed [<__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>]
# agent.current_state [4, 0]
# node.state [4, 0]
# node.parent <__main__.Node object at 0x000002317F07DD80>
# node.depth 4
# node.action [1, 0]
# node.path_cost 13
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>]
# succesors [<__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EBF0>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EBF0>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EBF0>]
# stack reversed [<__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>]
# agent.current_state [5, 0]
# node.state [5, 0]
# node.parent <__main__.Node object at 0x000002317F07E950>
# node.depth 5
# node.action [1, 0]
# node.path_cost 14
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>]
# succesors [<__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EEF0>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EEF0>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EEF0>]
# stack reversed [<__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>]
# agent.current_state [6, 0]
# node.state [6, 0]
# node.parent <__main__.Node object at 0x000002317F07EBF0>
# node.depth 6
# node.action [1, 0]
# node.path_cost 15
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>]
# succesors [<__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F190>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F190>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F190>]
# stack reversed [<__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>]
# agent.current_state [7, 0]
# node.state [7, 0]
# node.parent <__main__.Node object at 0x000002317F07EEF0>
# node.depth 7
# node.action [1, 0]
# node.path_cost 18
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>]
# succesors [<__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F490>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F490>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F490>]
# stack reversed [<__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>]
# agent.current_state [8, 0]
# node.state [8, 0]
# node.parent <__main__.Node object at 0x000002317F07F190>
# node.depth 8
# node.action [1, 0]
# node.path_cost 19
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>]
# succesors [<__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F730>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F730>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F730>]
# stack reversed [<__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>]
# agent.current_state [9, 0]
# node.state [9, 0]
# node.parent <__main__.Node object at 0x000002317F07F490>
# node.depth 9
# node.action [1, 0]
# node.path_cost 20
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>]
# succesors [<__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CC10>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CC10>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CC10>]
# stack reversed [<__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>]
# agent.current_state [10, 0]
# node.state [10, 0]
# node.parent <__main__.Node object at 0x000002317F07F730>
# node.depth 10
# node.action [1, 0]
# node.path_cost 21
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>]
# succesors [<__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CF10>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CF10>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CF10>]
# stack reversed [<__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>]
# agent.current_state [11, 0]
# node.state [11, 0]
# node.parent <__main__.Node object at 0x000002317F07CC10>
# node.depth 11
# node.action [1, 0]
# node.path_cost 27
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>]
# succesors [<__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D1B0>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D1B0>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D1B0>]
# stack reversed [<__main__.Node object at 0x000002317F07D1B0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>]
# agent.current_state [12, 0]
# node.state [12, 0]
# node.parent <__main__.Node object at 0x000002317F07CF10>
# node.depth 12
# node.action [1, 0]
# node.path_cost 33
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07D1B0>]
# succesors [<__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D390>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D390>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D390>]
# stack reversed [<__main__.Node object at 0x000002317F07D390>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>]
# agent.current_state [11, 0]
# node.state [11, 0]
# node.parent <__main__.Node object at 0x000002317F07D1B0>
# node.depth 13
# node.action [-1, 0]
# node.path_cost 39
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07D1B0>, <__main__.Node object at 0x000002317F07D390>]
# succesors [<__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D690>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D690>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D690>]
# stack reversed [<__main__.Node object at 0x000002317F07D690>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>]
# agent.current_state [12, 0]
# node.state [12, 0]
# node.parent <__main__.Node object at 0x000002317F07D390>
# node.depth 14
# node.action [1, 0]
# node.path_cost 45
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07D1B0>, <__main__.Node object at 0x000002317F07D390>, <__main__.Node object at 0x000002317F07D690>]
# succesors [<__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x000002317F07D870>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x000002317F07D870>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x000002317F07D870>]
# stack reversed [<__main__.Node object at 0x000002317F07D870>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>]
# agent.current_state [11, 0]
# node.state [11, 0]
# node.parent <__main__.Node object at 0x000002317F07D690>
# node.depth 15
# node.action [-1, 0]
# node.path_cost 51
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07D1B0>, <__main__.Node object at 0x000002317F07D390>, <__main__.Node object at 0x000002317F07D690>, <__main__.Node object at 0x000002317F07D870>]
# succesors [<__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x0000023100565F00>, <__main__.Node object at 0x0000023100566EC0>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x0000023100565F00>, <__main__.Node object at 0x0000023100566EC0>]
#
#
# stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x0000023100565F00>, <__main__.Node object at 0x0000023100566EC0>]
# stack reversed [<__main__.Node object at 0x0000023100566EC0>, <__main__.Node object at 0x0000023100565F00>, <__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317C4B0880>]
# pop stack: [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x0000023100565F00>]
# agent.current_state [12, 0]
# node.state [12, 0]
# node.parent <__main__.Node object at 0x000002317F07D870>
# node.depth 16
# node.action [1, 0]
# node.path_cost 57
# explored [<__main__.Node object at 0x000002317F07E1A0>, <__main__.Node object at 0x000002317F07D8D0>, <__main__.Node object at 0x000002317F07D900>, <__main__.Node object at 0x000002317F07DD80>, <__main__.Node object at 0x000002317F07E950>, <__main__.Node object at 0x000002317F07EBF0>, <__main__.Node object at 0x000002317F07EEF0>, <__main__.Node object at 0x000002317F07F190>, <__main__.Node object at 0x000002317F07F490>, <__main__.Node object at 0x000002317F07F730>, <__main__.Node object at 0x000002317F07CC10>, <__main__.Node object at 0x000002317F07CF10>, <__main__.Node object at 0x000002317F07D1B0>, <__main__.Node object at 0x000002317F07D390>, <__main__.Node object at 0x000002317F07D690>, <__main__.Node object at 0x000002317F07D870>, <__main__.Node object at 0x0000023100566EC0>]
# succesors [<__main__.Node object at 0x0000023100566C80>, <__main__.Node object at 0x0000023100566B90>]
# stack [<__main__.Node object at 0x000002317C4B0880>, <__main__.Node object at 0x000002317F07DAB0>, <__main__.Node object at 0x000002317F07E410>, <__main__.Node object at 0x000002317F07DDB0>, <__main__.Node object at 0x000002317F07D840>, <__main__.Node object at 0x000002317F07E860>, <__main__.Node object at 0x000002317F07E830>, <__main__.Node object at 0x000002317F07EA10>, <__main__.Node object at 0x000002317F07EB30>, <__main__.Node object at 0x000002317F07ED10>, <__main__.Node object at 0x000002317F07EDD0>, <__main__.Node object at 0x000002317F07EFB0>, <__main__.Node object at 0x000002317F07F0D0>, <__main__.Node object at 0x000002317F07F2B0>, <__main__.Node object at 0x000002317F07F370>, <__main__.Node object at 0x000002317F07F550>, <__main__.Node object at 0x000002317F07F670>, <__main__.Node object at 0x000002317F07CA30>, <__main__.Node object at 0x000002317F07CB50>, <__main__.Node object at 0x000002317F07CD30>, <__main__.Node object at 0x000002317F07CDF0>, <__main__.Node object at 0x000002317F07CFD0>, <__main__.Node object at 0x000002317F07D0F0>, <__main__.Node object at 0x000002317F07D2D0>, <__main__.Node object at 0x000002317F07D4B0>, <__main__.Node object at 0x000002317F07D570>, <__main__.Node object at 0x000002317F07D750>, <__main__.Node object at 0x00000231005663B0>, <__main__.Node object at 0x0000023100565F00>, <__main__.Node object at 0x0000023100566C80>, <__main__.Node object at 0x0000023100566B90>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 184
#     182 # g_node = uniform_cost_search(Ada)
#     183 g_node=depth_first_graph_search(Ada)
# --> 184 print(g_node.state)
#     185 # print(g_node.state)
#     186
#     187 # p = g_node.path()
#    (...)
#     202 # for i in range(map_copy.shape[0]):
#     203 #     print(map_copy[i,:])
#
# AttributeError: 'NoneType' object has no attribute 'state'
